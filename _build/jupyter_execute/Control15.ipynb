# %% [markdown]
# # Modelització de sistemes. Diagrama de blocs

# %% [markdown]
# ```{admonition} Pàgina en desenvolupament
# Encara estem treballant en aquest document.
# Esperem oferir-vos properament el seu contingut.
# Disculpeu les molèsties.
# ```

# %% [markdown]
# Podem descriure un sistema utilitzant diagrames funcionals on visuaitzem fàcilment com interaccionen els elements del sistema. Cada bloc del diagrama representa una operació matemàtica de les equacions que desriuen el sistema.
#
# Aquests diagrames de blocs van ser utilitzats per primera vegada amb el desenvolupament dels computadors analògics, que permeten simular el comportament dels sistemes dinàmics. Aquest diagrames no només es van trobar útils per visualitzar el sistema, també permetien fer una anàlisi preliminar d'un sistema sense utilitzar el computador {cite}`Simulation_block_diagrams`.
#
# Amb el temps es van desenvolupar eines per ordinador per a analitzar i simular sistemes dinàmics, molta gent va utilitzar el diagrama de blocs com la base de la representació del sistema i van utilitzar els diagrames per representar els seus models.

# %% [markdown]
# | Bloc | Operació |
# | :---: | :---: |
# | ![](img/Control/db01.png) | $y = C \cdot x $ |
# | ![](img/Control/db02.png) | $z = x - y $ |
# | ![](img/Control/db03.png) | $y = \int_{0}^{t}{x \cdot dt}$ |
# | ![](img/Control/db04.png) | $y = \frac{dx}{dt} $ |

# %% [markdown]
# ## Àlgebra de blocs
#
# Una vegada descrit el sistema amb un diagrama de blocs, voldrem simplificar al màxim aquest diagrama. Amb la taula d'equivalències següent es relativament fàcil optimitzar el diagrama:

# %% [markdown]
# | Bloc | Equivalent |
# | :---: | :---: |
# | ![](img/Control/db05.png) | ![](img/Control/db06.png) |
# | ![](img/Control/db07.png) | ![](img/Control/db08.png) |
# | ![](img/Control/db09.png) | ![](img/Control/db09b.png) |
# | ![](img/Control/db09.png) | ![](img/Control/db10.png) |
# | ![](img/Control/db11.png) | ![](img/Control/db12.png) |
# | ![](img/Control/db13.png) | ![](img/Control/db14.png) |
# | ![](img/Control/db15.png) | ![](img/Control/db16.png) |
# | ![](img/Control/db17.png) | ![](img/Control/db18.png) |
# | ![](img/Control/db19.png) | ![](img/Control/db20.png) |
# | ![](img/Control/db21.png) | ![](img/Control/db22.png) |
# | ![](img/Control/db23.png) | ![](img/Control/db24.png) |
# | ![](img/Control/db25.png) | ![](img/Control/db26.png) |
# | ![](img/Control/db25.png) | ![](img/Control/db26b.png) |

# %% [markdown]
# Al següent vídeo podeu veure com es justifiquen aquestes equivalències:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('JaLjcMqMr50')

# %% [markdown]
# ## Per a aprofundir en el tema
# * [Diagrama de Bloques en Sistemas de Control](https://controlautomaticoeducacion.com/control-realimentado/diagrama-de-bloques/)
