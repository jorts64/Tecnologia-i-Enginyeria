# %% [markdown]
# # Màquines elèctriques

# %% [markdown]
# $\Huge \textbf{Motors}$

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Zxdc1egljuI')

# %% [markdown]
# $\Huge \textbf{Generadors}$

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('rV47Of-MhfQ')

# %% [markdown]
# $\Huge \textbf{Transformadors}$

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('JG_BtY-mBZM')
