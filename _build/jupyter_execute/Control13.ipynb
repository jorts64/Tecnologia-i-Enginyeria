# %% [markdown]
# # PLCs

# %% [markdown]
# ```{admonition} Pàgina en desenvolupament
# Encara estem treballant en aquest document.
# Esperem oferir-vos properament el seu contingut.
# Disculpeu les molèsties.
# ```

# %% [markdown]
# Un controlador lògic programable, autòmat programable o PLC (de l'anglès **programmable logic controller**) , és un dispositiu de control econòmic, flexible i potent. Pot utilitzar tot tipus d'entrades i les sortides poden ser amb relès, transistors o triacs.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('NPsepHRSCls')

# %% [markdown]
# ## Programació ladder
#
# Aquest llenguatge de programació, que sembla una escala (en anglès ladder), és habitual en el PLCs, i és molt semblant als diagrames de contactes. Seleccioneu un exemple d'aquest simullador i veureu com és d'intiutiu.

# %%
# %%html
#  <iframe src="https://www.macroplc.com/simulador/" width="800" height="600"></iframe>
# Out:
#  <iframe src="https://www.macroplc.com/simulador/" width="800" height="600"></iframe>
