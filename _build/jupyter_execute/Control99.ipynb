# %% [markdown]
# # Recursos

# %% [markdown]
# ```{admonition} Pàgina en desenvolupament
# Encara estem treballant en aquest document.
# Esperem oferir-vos properament el seu contingut.
# Disculpeu les molèsties.
# ```

# %% [markdown]
# [Diagrama de Bloques en Sistemas de Control](https://controlautomaticoeducacion.com/control-realimentado/diagrama-de-bloques/)

# %%
# %%html
#  <iframe src="https://logic.ly/demo/" width="800" height="600"></iframe>
# Out:
#  <iframe src="https://logic.ly/demo/" width="800" height="600"></iframe>

# %% [markdown]
# [Biestable][https://es.wikipedia.org/wiki/Biestable]

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('HRJiow_k-V0')

# %% [markdown]
# [Amplificador Operacional](https://es.wikipedia.org/wiki/Amplificador_operacional)
# [Teoria PID](https://developer.wildernesslabs.co/Hardware/Reference/Algorithms/Proportional_Integral_Derivative/Intro/)
# [Llibreria Arduino FastPID](https://github.com/mike-matera/FastPID)

# %%
# %%html
#  <iframe src="https://recursos.citcea.upc.edu/grafcet/indice.html" width="800" height="600"></iframe>
# Out:
#  <iframe src="https://recursos.citcea.upc.edu/grafcet/indice.html" width="800" height="600"></iframe>
