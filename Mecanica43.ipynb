# %% [markdown]
# # Animacions de mecanismes 3D: FreeCAD

# %% [markdown]
# ```{admonition} Pàgina en desenvolupament
# Encara estem treballant en aquest document.
# Esperem oferir-vos properament el seu contingut.
# Disculpeu les molèsties.
# ```

# %% [markdown]
# **Important:** les versions anterior de FreeCAD a la 0.21 tenen un problema amb la traducció al català. Si el vostre sistema té una versió inferior, millor baixeu-vos l'[Appimage](https://www.freecad.org/downloads.php?lang=es_ES)

# %% [markdown]
# FreeCAD és un altre gran programari per disseny 3D. I també és lliure.
#
# Trobareu molts tutorials a la Internet. Cal destacar els generats per Juan González Gómez (Obijuan):
#
# | Wiki | YouTube |
# | :--- | :--- |
# |[Diseño de piezas con Freecad](http://www.iearobotics.com/wiki/index.php?title=Dise%C3%B1o_de_piezas_con_Freecad)|[Tutorial Freecad I](https://www.youtube.com/playlist?list=PLmnz0JqIMEzWQV-3ce9tVB_LFH9a91YHf)|
# |[Tutorial Freecad. Temporada 2](http://www.iearobotics.com/wiki/index.php?title=Tutorial_Freecad._Temporada_2)|[Tutorial Freecad II](https://www.youtube.com/playlist?list=PLmnz0JqIMEzUqEM-nxqhZoDaqszVXijOb)|
#
# FreeCAD permet macros en Python. Segons els seus autors, amb FreeCAD pots fer qualsevol cosa.

# %% [markdown]
# En aquest breu tutorial podeu veure com de fàcil és fer ua animaciód'un mecanisme amb FreeCAD:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('1CC6GnlVwGc')
